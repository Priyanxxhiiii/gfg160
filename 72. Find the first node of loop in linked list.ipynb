# %% [markdown]
# # Find the first node of loop in linked list

# %% [markdown]
# Given a head of the singly linked list. If a loop is present in the list then return the first node of the loop else return NULL.
#
# Custom Input format:
# A head of a singly linked list and a pos (1-based index) which denotes the position of the node to which the last node points to. If pos = 0, it means the last node points to null, indicating there is no loop.
#
# Examples:
#
# ##### Input:![image.png](attachment:ef8d89a1-f9c6-471b-8866-e988d91ae51a.png)![image.png](attachment:023cb671-cc4b-4983-9dd0-0d1d4f4855d4.png)
#
# ##### Output: 3
# Explanation: We can see that there exists a loop in the given linked list and the first node of the loop is 3.
# ##### Input:![image.png](attachment:c5932b39-2a1a-4f42-86bd-5ebabca912ec.png)![image.png](attachment:fe9d8e17-2b6c-4845-98f5-e919e657e414.png)
#
# ##### Output: -1
# Explanation: No loop exists in the above linked list.So the output is -1.
# ## Constraints:
# ##### 1 <= no. of nodes <= 10^6
# ##### 1 <= node->data <= 10^6

# %%
#User function Template for python3

class Node:
    def __init__(self, data):   # data -> value stored in node
        self.data = data
        self.next = None

class Solution:
    def findFirstNode(self, head):
        #code here
        slow=head
        fast=head
        while fast is not None and fast.next is not None:
            slow=slow.next
            fast=fast.next.next
            if slow==fast:
                slow=head
                while slow!=fast:
                    slow=slow.next
                    fast=fast.next
                return slow
        return None
